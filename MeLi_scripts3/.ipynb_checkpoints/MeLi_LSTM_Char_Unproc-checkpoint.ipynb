# %%
import numpy as np
import pandas as pd
from scipy import sparse
import matplotlib.pyplot as plt
from sklearn.metrics import balanced_accuracy_score as bas


import gc
gc.enable()

# %%
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.models import Sequential, Input
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping

from keras.optimizers import RMSprop, Adam
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, GRU
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
# Out:
# Using TensorFlow backend.

# %%
# data = pd.read_csv('../data-simplified-1-reduced-wordbal-800.csv')
data = pd.read_csv('../data-reduced-800-v3-shuffled.csv', index_col = 0)
# Out:
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
test = pd.read_csv('../test.csv')

# %%
catcode = pd.read_csv('../data-simplified-1-catcode.csv', header = None, names = ['category'])['category']

# %%
catcode.to_dict()
# Out:
# {0: '3D_GLASSES',
#  1: '3D_PENS',
#  2: '3D_PRINTERS',
#  3: '3D_PRINTER_FILAMENTS',
#  4: 'ABDOMINAL_TONING_BELTS',
#  5: 'ABS_SENSORS',
#  6: 'AB_ROLLER_WHEELS',
#  7: 'ACCORDIONS',
#  8: 'ACOUSTIC_GUITARS',
#  9: 'ACOUSTIC_PANELS',
#  10: 'ACTION_CAMERA_MOUNTS',
#  11: 'ACTION_FIGURES',
#  12: 'ADHESIVE_TAPES',
#  13: 'AEROBIC_CRUNCH_MACHINES',
#  14: 'AFTERSHAVES',
#  15: 'AGOGOS',
#  16: 'AIRBAGS',
#  17: 'AIRBAG_MODULES',
#  18: 'AIRBRUSHES',
#  19: 'AIRGUN_PELLETS',
#  20: 'AIRSOFT_GUNS',
#  21: 'AIR_COMPRESSORS',
#  22: 'AIR_CONDITIONERS',
#  23: 'AIR_CONDITIONER_REMOTE_CONTROLS',
#  24: 'AIR_FRESHENERS',
#  25: 'AIR_MATTRESSES',
#  26: 'ALARMS_AND_SENSORS',
#  27: 'ALARM_CLOCKS',
#  28: 'ALL_IN_ONE',
#  29: 'ALTERNATORS',
#  30: 'ALTERNATOR_PULLEYS',
#  31: 'AM_FM_RADIOS',
#  32: 'ANALOG_CAMERAS',
#  33: 'ANGLE_CLAMPS',
#  34: 'ANIMAL_AND_BALL_HOPPERS',
#  35: 'ANIMAL_CLIPPERS',
#  36: 'ANTIQUE_CHAIRS',
#  37: 'ANTIQUE_TAPE_RECORDERS',
#  38: 'ANTIQUE_TOY_CARS',
#  39: 'ANTIVIRUS_AND_INTERNET_SECURITY',
#  40: 'ANTI_STATIC_PLIERS',
#  41: 'ANTI_THEFT_STUDS',
#  42: 'APERITIFS',
#  43: 'AQUARIUM_FILTERS',
#  44: 'AQUARIUM_SKIMMERS',
#  45: 'ARCHERY_ARROWS',
#  46: 'ARCHERY_BOWS',
#  47: 'ARTIFICIAL_FEATHERS',
#  48: 'ARTIFICIAL_FLOWERS',
#  49: 'ARTIFICIAL_PLANTS',
#  50: 'ASPHALT_ROOFING_MEMBRANES',
#  51: 'AUDIO_AMPLIFIERS',
#  52: 'AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS',
#  53: 'AUDIO_AND_VIDEO_CONNECTORS',
#  54: 'AUDIO_INTERFACES',
#  55: 'AUTOMOBILE_FENDER_LINERS',
#  56: 'AUTOMOBILE_FUEL_PUMPS',
#  57: 'AUTOMOTIVE_AC_COMPRESSORS',
#  58: 'AUTOMOTIVE_AIR_FILTERS',
#  59: 'AUTOMOTIVE_AIR_FILTER_BOXES',
#  60: 'AUTOMOTIVE_AMPLIFIERS',
#  61: 'AUTOMOTIVE_ARMRESTS',
#  62: 'AUTOMOTIVE_BATTERIES',
#  63: 'AUTOMOTIVE_BLOWER_HEATER_MOTORS',
#  64: 'AUTOMOTIVE_BUMPER_GRILLES',
#  65: 'AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS',
#  66: 'AUTOMOTIVE_CLUTCH_DISCS',
#  67: 'AUTOMOTIVE_CLUTCH_KITS',
#  68: 'AUTOMOTIVE_CLUTCH_MASTER_CYLINDERS',
#  69: 'AUTOMOTIVE_CV_JOINT_BOOTS',
#  70: 'AUTOMOTIVE_DEFLECTORS',
#  71: 'AUTOMOTIVE_DOORS',
#  72: 'AUTOMOTIVE_DOOR_PANELS',
#  73: 'AUTOMOTIVE_EMBLEMS',
#  74: 'AUTOMOTIVE_ENGINE_COOLANT_THERMOSTATS',
#  75: 'AUTOMOTIVE_ENGINE_CYLINDER_HEADS',
#  76: 'AUTOMOTIVE_ENGINE_MOUNTS',
#  77: 'AUTOMOTIVE_ENGINE_VALVE_COVERS',
#  78: 'AUTOMOTIVE_FENDERS',
#  79: 'AUTOMOTIVE_FRONT_BUMPERS',
#  80: 'AUTOMOTIVE_FUEL_TANKS',
#  81: 'AUTOMOTIVE_FUEL_TANK_DOORS',
#  82: 'AUTOMOTIVE_HEADLIGHTS',
#  83: 'AUTOMOTIVE_HEATER_VALVES',
#  84: 'AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS',
#  85: 'AUTOMOTIVE_MIRROR_COVERS',
#  86: 'AUTOMOTIVE_MOLDINGS',
#  87: 'AUTOMOTIVE_NERF_BARS',
#  88: 'AUTOMOTIVE_OIL_FILTERS',
#  89: 'AUTOMOTIVE_PAINTS',
#  90: 'AUTOMOTIVE_POWER_WINDOW_REGULATORS',
#  91: 'AUTOMOTIVE_REAR_BODY_TAIL_LIGHT_PANELS',
#  92: 'AUTOMOTIVE_SEATS',
#  93: 'AUTOMOTIVE_SHIFT_LEVER_KNOBS',
#  94: 'AUTOMOTIVE_SHOCK_ABSORBERS',
#  95: 'AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS',
#  96: 'AUTOMOTIVE_SIDE_VIEW_MIRRORS',
#  97: 'AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES',
#  98: 'AUTOMOTIVE_SPRING_SUSPENSIONS',
#  99: 'AUTOMOTIVE_STEERING_WHEELS',
#  100: 'AUTOMOTIVE_SUSPENSION_CONTROL_ARMS',
#  101: 'AUTOMOTIVE_THROTTLE_BODIES',
#  102: 'AUTOMOTIVE_TIMING_BELTS',
#  103: 'AUTOMOTIVE_TIRES',
#  104: 'AUTOMOTIVE_TRANSMISSION_GEARS',
#  105: 'AUTOMOTIVE_TRUNK_LIDS',
#  106: 'AUTOMOTIVE_WATER_PUMPS',
#  107: 'AUTOMOTIVE_WEATHERSTRIPS',
#  108: 'AUTOMOTIVE_WHEEL_COVERS',
#  109: 'AV_RECEIVERS',
#  110: 'AXES',
#  111: 'BABIES_FOOTWEAR',
#  112: 'BABIES_FORMULA',
#  113: 'BABY_ACTIVITY_TABLES',
#  114: 'BABY_BLANKETS',
#  115: 'BABY_BODYSUITS',
#  116: 'BABY_BOTTLES',
#  117: 'BABY_BOTTLE_WARMERS',
#  118: 'BABY_BOUNCERS',
#  119: 'BABY_CAR_SEATS',
#  120: 'BABY_CHANGING_PADS',
#  121: 'BABY_CLOTHING_SETS',
#  122: 'BABY_DIAPERS',
#  123: 'BABY_GROOMING_KITS',
#  124: 'BABY_GYMS',
#  125: 'BABY_HIGH_CHAIRS',
#  126: 'BABY_JUMPERS',
#  127: 'BABY_MONITORS',
#  128: 'BABY_PACIFIERS',
#  129: 'BABY_PACIFIER_CLIPS',
#  130: 'BABY_PLAYARDS',
#  131: 'BABY_SAFETY_LOCKS',
#  132: 'BABY_STERILIZERS',
#  133: 'BABY_STROLLERS',
#  134: 'BABY_SWIMWEAR',
#  135: 'BABY_WALKERS',
#  136: 'BACKPACKS',
#  137: 'BALLOONS',
#  138: 'BALL_PIT_BALLS',
#  139: 'BARBECUE_TOOL_SETS',
#  140: 'BAR_CLAMPS',
#  141: 'BAR_CODE_SCANNERS',
#  142: 'BAR_SOAPS',
#  143: 'BASEBALL_AND_SOFTBALL_BATS',
#  144: 'BASEBOARDS',
#  145: 'BASKETBALL_BACKBOARDS_AND_HOOPS',
#  146: 'BASKETBALL_JERSEYS',
#  147: 'BASKET_BALLS',
#  148: 'BASS_GUITARS',
#  149: 'BATHROOM_ACCESSORIES_SETS',
#  150: 'BATHROOM_FAUCETS',
#  151: 'BATHROOM_FAUCET_SETS',
#  152: 'BATHROOM_GRAB_BARS',
#  153: 'BATHROOM_SINKS',
#  154: 'BATHROOM_VANITIES',
#  155: 'BATTERY_CHARGERS',
#  156: 'BDSM_BLINDFOLDS',
#  157: 'BDSM_GAGS',
#  158: 'BDSM_HANDCUFFS',
#  159: 'BDSM_WHIPS',
#  160: 'BEACH_BALLS',
#  161: 'BEACH_PADDLES',
#  162: 'BEAUTY_WIGS',
#  163: 'BEDLINERS',
#  164: 'BEDROOM_SETS',
#  165: 'BEDS',
#  166: 'BED_SHEETS',
#  167: 'BEERS',
#  168: 'BEER_BREWING_EQUIPMENTS',
#  169: 'BEER_DISPENSERS',
#  170: 'BEER_FAUCETS',
#  171: 'BEER_KEGS',
#  172: 'BELTS',
#  173: 'BICYCLES',
#  174: 'BICYCLE_AND_MOTORCYCLE_ALARMS',
#  175: 'BICYCLE_BAGS',
#  176: 'BICYCLE_COVERS',
#  177: 'BICYCLE_FRAMES',
#  178: 'BICYCLE_HANDLEBARS',
#  179: 'BICYCLE_PEDALS',
#  180: 'BICYCLE_SEATS',
#  181: 'BICYCLE_TIRE_REPAIR_KITS',
#  182: 'BICYCLE_WHEELS',
#  183: 'BILLIARD_TABLES',
#  184: 'BILL_COUNTERS',
#  185: 'BINDING_SPINES',
#  186: 'BINOCULARS',
#  187: 'BIRD_DRINKERS_AND_FEEDERS',
#  188: 'BIRD_TOYS',
#  189: 'BLANKETS',
#  190: 'BLANK_DISCS',
#  191: 'BLENDERS',
#  192: 'BLOOD_PRESSURE_MONITORS',
#  193: 'BLOUSES',
#  194: 'BLU_RAY_PLAYERS',
#  195: 'BOARD_GAMES',
#  196: 'BODYBOARDS',
#  197: 'BODYWEIGHT_SCALES',
#  198: 'BODY_SHAPERS',
#  199: 'BODY_SKIN_CARE_PRODUCTS',
#  200: 'BOMBOS',
#  201: 'BONGOS',
#  202: 'BOOKCASES',
#  203: 'BOOKS',
#  204: 'BOOTS',
#  205: 'BOTTLE_OPENERS',
#  206: 'BOXING_HEADGEARS',
#  207: 'BOXING_SPEED_BAGS',
#  208: 'BOX_SPRING_AND_MATTRESS_SETS',
#  209: 'BRACELETS_AND_ANKLE_BRACES',
#  210: 'BRAKE_BOOSTERS',
#  211: 'BRAKE_DRUMS',
#  212: 'BRAKE_LIGHTS',
#  213: 'BRAKE_LIGHT_SWITCHES',
#  214: 'BRAKE_MASTER_CYLINDERS',
#  215: 'BRAS',
#  216: 'BREADS',
#  217: 'BREAD_MAKERS',
#  218: 'BREAKFASTS_AND_AFTERNOON_TEAS',
#  219: 'BREAST_FEEDING_PILLOWS',
#  220: 'BRICKS',
#  221: 'BRIEFCASES',
#  222: 'BROCHURES',
#  223: 'BROCHURE_HOLDERS',
#  224: 'BRUSH_CUTTERS',
#  225: 'BUBBLE_MACHINES',
#  226: 'BUCKETS_AND_BASINS',
#  227: 'BUMPER_IMPACT_ABSORBERS',
#  228: 'BUTTON_PINS',
#  229: 'BUTT_PLUGS',
#  230: 'CABIN_FILTERS',
#  231: 'CACAO',
#  232: 'CACHACAS',
#  233: 'CAKES',
#  234: 'CAKE_STANDS',
#  235: 'CAKE_TOPPERS',
#  236: 'CALCULATORS',
#  237: 'CALIPERS',
#  238: 'CAMERAS',
#  239: 'CAMERA_AND_CELLPHONE_STABILIZERS',
#  240: 'CAMERA_AND_VIDEO_CAMERA_BAGS_AND_CASES',
#  241: 'CAMERA_BATTERIES',
#  242: 'CAMERA_BATTERY_GRIPS',
#  243: 'CAMERA_CASES',
#  244: 'CAMERA_CHARGERS',
#  245: 'CAMERA_CRANES',
#  246: 'CAMERA_FLASHES',
#  247: 'CAMERA_LENSES',
#  248: 'CAMERA_MONOPODS',
#  249: 'CAMERA_PHOTOMETERS',
#  250: 'CAMERA_REPLACEMENT_DISPLAYS',
#  251: 'CAMERA_STRAPS',
#  252: 'CAMERA_TRIPODS',
#  253: 'CAMPING_CHAIRS',
#  254: 'CAMPING_STOVES',
#  255: 'CANDIES',
#  256: 'CANDLES',
#  257: 'CANDLE_HOLDERS',
#  258: 'CANOES',
#  259: 'CAN_OPENERS',
#  260: 'CARABINERS',
#  261: 'CARDS_AND_INVITATIONS',
#  262: 'CARD_PAYMENT_TERMINALS',
#  263: 'CARPETS',
#  264: 'CAR_AC_CONDENSERS',
#  265: 'CAR_AC_DASHBOARD_VENTS',
#  266: 'CAR_AC_EXPANSION_VALVES',
#  267: 'CAR_AC_HOSE_ASSEMBLIES',
#  268: 'CAR_AIR_FRESHENERS',
#  269: 'CAR_ANTENNAS',
#  270: 'CAR_AV_RECEIVERS',
#  271: 'CAR_CARBURETORS',
#  272: 'CAR_CENTER_CONSOLES',
#  273: 'CAR_DISTRIBUTOR_CAPS',
#  274: 'CAR_DOOR_HINGES',
#  275: 'CAR_EMERGENCY_KITS',
#  276: 'CAR_ENGINE_CAMSHAFTS',
#  277: 'CAR_ENGINE_CAMSHAFT_SENSORS',
#  278: 'CAR_EXHAUSTS',
#  279: 'CAR_FRONT_MASKS',
#  280: 'CAR_GEARBOXES',
#  281: 'CAR_HOODS',
#  282: 'CAR_INTERCOOLERS',
#  283: 'CAR_LIGHT_BULBS',
#  284: 'CAR_POWER_STEERING_PUMPS',
#  285: 'CAR_SCANNERS',
#  286: 'CAR_SCREENS',
#  287: 'CAR_SEAT_COVERS',
#  288: 'CAR_SPOILERS',
#  289: 'CAR_STEREOS',
#  290: 'CAR_TURN_SIGNAL_LIGHTS',
#  291: 'CAR_WHEELS',
#  292: 'CAR_WINDOW_SWITCHES',
#  293: 'CASH_DRAWERS',
#  294: 'CASH_REGISTERS',
#  295: 'CATHETERS',
#  296: 'CATS',
#  297: 'CATS_AND_DOGS_FOODS',
#  298: 'CATS_AND_DOGS_TREATS',
#  299: 'CATS_LITTER',
#  300: 'CAT_SCRATCHERS',
#  301: 'CD_AND_DVD_PLAYERS',
#  302: 'CEILING_LIGHTS',
#  303: 'CELLPHONES',
#  304: 'CELLPHONE_AND_TABLET_CASES',
#  305: 'CELLPHONE_BATTERIES',
#  306: 'CELLPHONE_COVERS',
#  307: 'CELLPHONE_REPAIR_TOOL_KITS',
#  308: 'CELLPHONE_REPLACEMENT_CAMERAS',
#  309: 'CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS',
#  310: 'CELLPHONE_USB_AND_AUXILIARY_ADAPTERS',
#  311: 'CELL_BATTERIES',
#  312: 'CEMENT',
#  313: 'CENTRIFUGAL_PUMPS',
#  314: 'CERAMIC_KILNS',
#  315: 'CERAMIC_TILES',
#  316: 'CEREALS',
#  317: 'CEREAL_BARS',
#  318: 'CERVICAL_COLLARS',
#  319: 'CHAFING_DISHES',
#  320: 'CHALKBOARDS_AND_WHITEBOARDS',
#  321: 'CHALKBOARD_AND_WHITEBOARD_ERASERS',
#  322: 'CHAMPAGNES',
#  323: 'CHARANGOS',
#  324: 'CHARCOAL_GRILLS',
#  325: 'CHARMS_AND_MEDALS',
#  326: 'CHECKOUT_COUNTERS',
#  327: 'CHESS_CLOCKS',
#  328: 'CHESTS',
#  329: 'CHIPPER_SHREDDERS',
#  330: 'CHIP_AND_DIP_SERVERS',
#  331: 'CHISELS',
#  332: 'CHOCOLATES',
#  333: 'CHOCOLATE_WATERFALLS',
#  334: 'CHRISTMAS_LIGHTS',
#  335: 'CHRISTMAS_TREES',
#  336: 'CHRISTMAS_TREE_ORNAMENTS',
#  337: 'CHURRO_MAKING_MACHINES',
#  338: 'CIRCUIT_BREAKERS',
#  339: 'CLARINETS',
#  340: 'CLASSIC_CARS',
#  341: 'CLEANING_CLOTHS',
#  342: 'CLEANING_GLOVES',
#  343: 'CLEANING_SPONGES',
#  344: 'CLOTHES_HANGERS',
#  345: 'CLOTHING_PATCHES',
#  346: 'CLUTCH_BEARINGS',
#  347: 'CLUTCH_FORKS',
#  348: 'CLUTCH_SLAVE_CYLINDERS',
#  349: 'CNC_LATHES',
#  350: 'CNC_MACHINING_CENTERS',
#  351: 'COASTERS',
#  352: 'COAT_RACKS',
#  353: 'COFFEE_CAPSULES',
#  354: 'COFFEE_MAKERS',
#  355: 'COFFEE_POD_HOLDERS',
#  356: 'COFFEE_TABLES',
#  357: 'COFFEE_VENDING_MACHINES',
#  358: 'COGNACS',
#  359: 'COIL_BINDING_MACHINES',
#  360: 'COIN_PURSES',
#  361: 'COLANDERS',
#  362: 'COLD_FOOD_AND_DRINK_VENDING_MACHINES',
#  363: 'COLD_ROOMS',
#  364: 'COLLECTIBLE_CANS_BOTTLES_AND_SODA_SIPHONS',
#  365: 'COLLECTIBLE_POSTCARDS',
#  366: 'COMBS',
#  367: 'COMBUSTION_CHAINSAWS',
#  368: 'COMBUSTION_WATER_PUMPS',
#  369: 'COMFORTERS',
#  370: 'COMICS',
#  371: 'COMMERCIAL_AND_EVENT_BAGS',
#  372: 'COMMERCIAL_LIGHT_SIGNS',
#  373: 'COMMERCIAL_POPCORN_MACHINES',
#  374: 'COMPLETE_SKATEBOARDS',
#  375: 'COMPOSTERS',
#  376: 'COMPRESSED_AIR_DUSTERS',
#  377: 'COMPRESSION_SLEEVES',
#  378: 'COMPUTER_AND_TV_FLEX_CABLES',
#  379: 'COMPUTER_MONITORS',
#  380: 'COMPUTER_MOTHERBOARDS',
#  381: 'COMPUTER_PROCESSORS',
#  382: 'CONCEALERS',
#  383: 'CONCERTINA_WIRES',
#  384: 'CONCERT_TICKETS',
#  385: 'CONCRETE_BLOCKS',
#  386: 'CONDOMS',
#  387: 'CONFETTI_SHOOTERS',
#  388: 'CONNECTING_COUPLERS',
#  389: 'CONSTRUCTION_BEAMS',
#  390: 'CONSTRUCTION_FINISHING_TROWELS',
#  391: 'CONSTRUCTION_LIME_BAGS',
#  392: 'CONSTRUCTION_PROFILES',
#  393: 'CONSTRUCTION_SAND',
#  394: 'CONTINUOUS_INK_SYSTEMS',
#  395: 'CONTINUOUS_LIGHTING',
#  396: 'CONTROLLER_PADS',
#  397: 'COOKIES',
#  398: 'COOKIES_CUTTERS',
#  399: 'COOKING_OILS',
#  400: 'COOKING_PLOW_DISCS',
#  401: 'COOKING_SCALES',
#  402: 'COOKTOPS',
#  403: 'CORKSCREWS',
#  404: 'CORRECTION_TAPES_AND_FLUIDS',
#  405: 'CORSETS',
#  406: 'COSTUMES',
#  407: 'COTTON_CANDY_MACHINES',
#  408: 'COUNTERFEIT_MONEY_DETECTOR_MACHINE',
#  409: 'COUNTERTOPS',
#  410: 'CPR_TRAINING_MANIKINS',
#  411: 'CRANKSHAFTS',
#  412: 'CRASHED_CARS',
#  413: 'CRAYONS',
#  414: 'CRIBS',
#  415: 'CRIB_BEDDING_SETS',
#  416: 'CROWBARS',
#  417: 'CRUTCHES',
#  418: 'CUE_STICKS',
#  419: 'CUPCAKES_MAKERS',
#  420: 'CUPCAKE_STANDS',
#  421: 'CURLING_IRONS',
#  422: 'CUSHIONS',
#  423: 'CUSHION_COVERS',
#  424: 'CUTTING_BOARDS',
#  425: 'CUT_OFF_AND_GRINDING_WHEELS',
#  426: 'CV_JOINTS',
#  427: 'CYCLING_COMPUTERS',
#  428: 'CYCLING_HELMETS',
#  429: 'CYMBALS',
#  430: 'DATA_CABLES_AND_ADAPTERS',
#  431: 'DEBRIS_BAGS',
#  432: 'DECORATIVE_BASKETS',
#  433: 'DECORATIVE_BOXES',
#  434: 'DECORATIVE_COLUMNS',
#  435: 'DECORATIVE_PAINTINGS',
#  436: 'DECORATIVE_PANELS',
#  437: 'DECORATIVE_TILES_AND_MOSAICS',
#  438: 'DECORATIVE_VASES',
#  439: 'DECORATIVE_VINYLS',
#  440: 'DEEP_FRYERS',
#  441: 'DEHUMIDIFIERS',
#  442: 'DENTAL_CHAIRS',
#  443: 'DENTAL_CURING_LIGHTS',
#  444: 'DENTAL_FLOSSES',
#  445: 'DENTAL_PLIERS',
#  446: 'DEODORANTS',
#  447: 'DESIGN_AND_MULTIMEDIA_SOFTWARE',
#  448: 'DESKTOP_COMPUTERS',
#  449: 'DESKTOP_COMPUTER_CASES',
#  450: 'DESKTOP_COMPUTER_COOLERS_AND_FANS',
#  451: 'DESKTOP_COMPUTER_POWER_SUPPLIES',
#  452: 'DEVICE_PROGRAMMERS',
#  453: 'DIAPER_BAGS',
#  454: 'DIECAST_VEHICLES',
#  455: 'DIESEL_VACUUM_PUMPS',
#  456: 'DIFFERENTIALS',
#  457: 'DIGITAL_PORTABLE_MEDIA_PLAYERS',
#  458: 'DIGITAL_VOICE_RECORDERS',
#  459: 'DIGITAL_WEATHER_STATIONS',
#  460: 'DILDOS',
#  461: 'DINING_CHAIRS',
#  462: 'DINING_SETS',
#  463: 'DINING_TABLES',
#  464: 'DISC_BRAKE_CALIPER_PISTONS',
#  465: 'DISC_PACKAGINGS',
#  466: 'DISHES_PLATES',
#  467: 'DISHES_RACKS',
#  468: 'DISHWASHERS',
#  469: 'DISPOSABLE_CUPS',
#  470: 'DISPOSABLE_GLOVES',
#  471: 'DISPOSABLE_PARTY_KITS',
#  472: 'DISTRIBUTION_KITS',
#  473: 'DIVING_KNIVES',
#  474: 'DIVING_MASKS',
#  475: 'DJEMBES',
#  476: 'DJ_CASES',
#  477: 'DJ_CONTROLLERS',
#  478: 'DJ_EFFECTS_PROCESSORS',
#  479: 'DJ_TURNTABLES',
#  480: 'DOG_AND_CAT_SHAMPOOS_AND_CONDITIONERS',
#  481: 'DOG_BEDS',
#  482: 'DOG_CARRIERS_AND_CARRYING_BAGS',
#  483: 'DOG_LEASHES',
#  484: 'DOG_LIFE_JACKETS',
#  485: 'DOG_NAIL_CLIPPERS',
#  486: 'DOLLHOUSES',
#  487: 'DOLLS',
#  488: 'DOORBELLS',
#  489: 'DOORS',
#  490: 'DOOR_AND_GATE_REMOTE_CONTROLS',
#  491: 'DOOR_AND_WINDOW_LOCKS',
#  492: 'DRAWERS',
#  493: 'DRAWING_BOARDS_AND_TABLES',
#  494: 'DRAWING_COMPASSES',
#  495: 'DRESSES',
#  496: 'DRIED_FRUITS',
#  497: 'DRILLS_SCREWDRIVERS',
#  498: 'DRILL_BITS',
#  499: 'DRINKING_GLASSES',
#  500: 'DRINK_PITCHERS',
#  501: 'DRIVE_SHAFTS',
#  502: 'DRONES',
#  503: 'DRONE_BATTERIES',
#  504: 'DRONE_PROPELLERS',
#  505: 'DRUMS',
#  506: 'DRUMSTICKS_MALLETS_AND_BRUSHES',
#  507: 'DRUM_BRAKE_SHOES',
#  508: 'DRUM_PEDALS',
#  509: 'DRUM_STANDS',
#  510: 'DRYER_MACHINES',
#  511: 'DRYING_RACKS',
#  512: 'DRYWALLS',
#  513: 'DULCE_DE_LECHE',
#  514: 'DVD_RECORDERS',
#  515: 'DVR_RECORDERS',
#  516: 'EARRINGS',
#  517: 'EASELS',
#  518: 'EASTER_EGGS',
#  519: 'ECG_MACHINES',
#  520: 'ECT_SENSORS',
#  521: 'EDIBLE_SEEDS',
#  522: 'EGGS',
#  523: 'EGR_VALVES',
#  524: 'ELBOW_SUPPORTS',
#  525: 'ELECTRICAL_CABLES',
#  526: 'ELECTRICAL_OUTLETS',
#  527: 'ELECTRICAL_TIMERS',
#  528: 'ELECTRICITY_METERS',
#  529: 'ELECTRIC_AIR_PUMPS',
#  530: 'ELECTRIC_BATHROOM_FAUCETS',
#  531: 'ELECTRIC_BLOWERS',
#  532: 'ELECTRIC_BROOMS',
#  533: 'ELECTRIC_CAN_OPENERS',
#  534: 'ELECTRIC_CHAINSAWS',
#  535: 'ELECTRIC_DEMOLITION_HAMMERS',
#  536: 'ELECTRIC_DRILLS',
#  537: 'ELECTRIC_FOOD_STEAMERS',
#  538: 'ELECTRIC_GLUE_GUNS',
#  539: 'ELECTRIC_GRILLS',
#  540: 'ELECTRIC_GUITARS',
#  541: 'ELECTRIC_HAND_PLANERS',
#  542: 'ELECTRIC_KNIVES',
#  543: 'ELECTRIC_LAWN_MOWERS',
#  544: 'ELECTRIC_PRESSURE_WASHERS',
#  545: 'ELECTRIC_SAWS',
#  546: 'ELECTRIC_SCREWDRIVERS',
#  547: 'ELECTRIC_SHOWER_HEADS',
#  548: 'ELECTROLYTIC_CAPACITORS',
#  549: 'ELECTRONIC_DRUMS',
#  550: 'ELECTRONIC_ENTRANCE_INTERCOMS',
#  551: 'ELECTRONIC_LOCKS',
#  552: 'ELECTRONIC_MUSCLE_STIMULATORS',
#  553: 'ELECTRONIC_SWITCHES',
#  554: 'ELLIPTICAL_MACHINES',
#  555: 'EMBROIDERY_DESIGNS',
#  556: 'EMBROIDERY_MACHINES',
#  557: 'EMERGENCY_LIGHTS',
#  558: 'EMPLOYEE_TIME_CLOCKS',
#  559: 'ENERGETIC_STONES',
#  560: 'ENGINE_BEARINGS',
#  561: 'ENGINE_CONNECTING_RODS',
#  562: 'ENGINE_CONTROL_MODULES',
#  563: 'ENGINE_COOLING_FAN_CLUTCHES',
#  564: 'ENGINE_COOLING_FAN_MOTORS',
#  565: 'ENGINE_COOLING_FAN_SHROUDS',
#  566: 'ENGINE_COOLING_FAN_SWITCHES',
#  567: 'ENGINE_CRANKSHAFT_POSITION_SENSORS',
#  568: 'ENGINE_CRANKSHAFT_PULLEYS',
#  569: 'ENGINE_CYLINDER_HEAD_BOLTS',
#  570: 'ENGINE_GASKET_SETS',
#  571: 'ENGINE_INTAKE_HOSES',
#  572: 'ENGINE_INTAKE_MANIFOLDS',
#  573: 'ENGINE_OILS',
#  574: 'ENGINE_OIL_DIPSTICKS',
#  575: 'ENGINE_OIL_PRESSURE_SENSORS',
#  576: 'ENGINE_PISTONS',
#  577: 'ENGINE_TAPPET_GUIDE_HOLDS',
#  578: 'ENGINE_VALVES',
#  579: 'ENGINE_VALVES_SPRING_RETAINERS',
#  580: 'EPILATORS',
#  581: 'EQUALIZERS',
#  582: 'ERASERS',
#  583: 'EROTIC_ANAL_AND_VAGINAL_DOUCHES',
#  584: 'EROTIC_BALLS',
#  585: 'EROTIC_BOOKS',
#  586: 'EROTIC_COSTUMES',
#  587: 'EROTIC_CREAMS',
#  588: 'EROTIC_MAGAZINES',
#  589: 'EROTIC_MALE_UNDERWEAR',
#  590: 'EROTIC_MASSAGE_OILS',
#  591: 'EROTIC_PUMPS',
#  592: 'ESPADRILLES',
#  593: 'ESSENTIAL_OILS',
#  594: 'EXERCISE_MATS',
#  595: 'EXHAUST_MANIFOLDS',
#  596: 'EXTERNAL_LAPTOP_COOLERS',
#  597: 'EYELINERS',
#  598: 'EYESHADOWS',
#  599: 'FABRICS',
#  600: 'FABRIC_SOFTENERS',
#  601: 'FACE_MASKS',
#  602: 'FACE_POWDERS',
#  603: 'FACIAL_SKIN_CARE_PRODUCTS',
#  604: 'FALSE_CEILINGS',
#  605: 'FALSE_EYELASHES',
#  606: 'FANNY_PACKS',
#  607: 'FANS',
#  608: 'FAN_PROPELLERS',
#  609: 'FAX_MACHINES',
#  610: 'FETAL_DOPPLERS',
#  611: 'FIBER_OPTIC_SPLITTERS',
#  612: 'FIDGET_SPINNERS',
#  613: 'FIELD_HOCKEY_STICKS',
#  614: 'FILING_CABINETS',
#  615: 'FINGERPRINT_READERS',
#  616: 'FIRE_EXTINGUISHERS',
#  617: 'FIRST_AID_KITS',
#  618: 'FISHES',
#  619: 'FISHING_LINES',
#  620: 'FISHING_LURES',
#  621: 'FISHING_REELS',
#  622: 'FISHING_RODS',
#  623: 'FISHING_ROD_CASES',
#  624: 'FISHING_TACKLE_BOXES',
#  625: 'FISHING_VESTS',
#  626: 'FISH_TANKS',
#  627: 'FISH_TANK_THERMOSTATS',
#  628: 'FITNESS_TRAMPOLINES',
#  629: 'FLASHLIGHTS',
#  630: 'FLASH_TRIGGERS',
#  631: 'FLATS',
#  632: 'FLATWARE_ORGANIZERS',
#  633: 'FLATWARE_SETS',
#  634: 'FLEA_AND_TICK_TREATMENTS',
#  635: 'FLOOD_LIGHTS',
#  636: 'FLOOR_LAMPS',
#  637: 'FLOOR_PAINTS',
#  638: 'FLOUR',
#  639: 'FLUTES',
#  640: 'FOG_LIGHTS',
#  641: 'FOLDERS_AND_EXPANDING_FILES',
#  642: 'FOLDING_SCREENS',
#  643: 'FOOD_AND_DRINK_COLORINGS',
#  644: 'FOOD_CARTS',
#  645: 'FOOD_PACKAGING_BOXES',
#  646: 'FOOD_PROCESSORS',
#  647: 'FOOD_SLICERS',
#  648: 'FOOD_STORAGE_CONTAINERS',
#  649: 'FOOSBALL_TABLES',
#  650: 'FOOTBALL_BALLS',
#  651: 'FOOTBALL_CAPS',
#  652: 'FOOTBALL_GOALKEEPER_GLOVES',
#  653: 'FOOTBALL_GOALS',
#  654: 'FOOTBALL_JACKETS',
#  655: 'FOOTBALL_KITS',
#  656: 'FOOTBALL_SHIRTS',
#  657: 'FOOTBALL_SHOES',
#  658: 'FOOT_BATH_MASSAGERS',
#  659: 'FORCE_GAUGES',
#  660: 'FOUNDATIONS',
#  661: 'FRAME_POOLS',
#  662: 'FRANKLIN_STOVES',
#  663: 'FREEZERS',
#  664: 'FREEZER_BAGS',
#  665: 'FUEL_INJECTION_RAILS',
#  666: 'FUEL_INJECTORS',
#  667: 'FUEL_LEVEL_FLOATS',
#  668: 'FURNITURE_KNOBS',
#  669: 'FUTONS',
#  670: 'GAMEPADS_AND_JOYSTICKS',
#  671: 'GAME_CONSOLES',
#  672: 'GAME_CONSOLE_AND_VIDEO_GAME_CONTROLLER_SKINS',
#  673: 'GARAGE_DOORS',
#  674: 'GARDENING_AND_AGRICULTURE_SEEDS',
#  675: 'GARDENING_AND_CONSTRUCTION_SHOVELS',
#  676: 'GARDEN_BENCHES',
#  677: 'GARDEN_CHAIRS',
#  678: 'GARDEN_HOSES',
#  679: 'GARDEN_SHEDS',
#  680: 'GARDEN_SOIL',
#  681: 'GAS_BOILERS',
#  682: 'GAS_CYLINDERS',
#  683: 'GAS_DETECTORS',
#  684: 'GAS_LIFT_SUPPORTS',
#  685: 'GATE_GEAR_RACKS',
#  686: 'GATE_MOTORS',
#  687: 'GAUZES',
#  688: 'GAZEBOS',
#  689: 'GEL_NAIL_KITS',
#  690: 'GIFT_CARDS',
#  691: 'GINS',
#  692: 'GLASSES_FRAMES',
#  693: 'GLASS_BLOCKS',
#  694: 'GLASS_CUTTERS',
#  695: 'GLOW_PLUGS',
#  696: 'GLOW_PLUG_CONTROLLERS',
#  697: 'GOAL_NETS',
#  698: 'GOLF_BAGS',
#  699: 'GOLF_CLUBS_SETS',
#  700: 'GOLF_CLUBS_WOODS_AND_HYBRIDS',
#  701: 'GONDOLA_SHELVING_UNITS',
#  702: 'GPS',
#  703: 'GRAPHICS_CARDS',
#  704: 'GRAPHICS_TABLETS',
#  705: 'GREEN_WALLS_AND_LIVING_PAINTINGS',
#  706: 'GRILL_GRATES',
#  707: 'GRIPS_AND_OVERGRIPS',
#  708: 'GROOMING_TABLES',
#  709: 'GROOVE_JOINT_PLIERS',
#  710: 'GROUND_AND_WHOLE_BEANS_COFFEE',
#  711: 'GUITAR_PICKS',
#  712: 'GUITAR_STRINGS',
#  713: 'GUN_HOLSTERS',
#  714: 'GYM_BARS',
#  715: 'GYM_DUMBBELLS',
#  716: 'GYM_GLOVES',
#  717: 'HABERDASHERY_BEADS',
#  718: 'HABERDASHERY_LACE_EDGINGS',
#  719: 'HABERDASHERY_RIBBONS',
#  720: 'HAIRDRESSING_CAPES',
#  721: 'HAIRDRESSING_CAPS',
#  722: 'HAIRDRESSING_SCISSORS',
#  723: 'HAIR_BRUSHES',
#  724: 'HAIR_CLIPPERS',
#  725: 'HAIR_DRYERS',
#  726: 'HAIR_MOLDING_AND_STYLING',
#  727: 'HAIR_SHAMPOOS_AND_CONDITIONERS',
#  728: 'HAIR_STRAIGHTENERS',
#  729: 'HAIR_STRAIGHTENING_BRUSHES',
#  730: 'HAIR_TREATMENTS',
#  731: 'HAMBURGER_FORMERS',
#  732: 'HAMMER_DRILLS',
#  733: 'HAMMOCKS',
#  734: 'HANDBAGS',
#  735: 'HANDBALL_BALLS',
#  736: 'HANDICRAFT_BOXES',
#  737: 'HAND_AND_FOOT_CREAMS',
#  738: 'HAND_BLENDERS',
#  739: 'HAND_BRAKE_CABLES',
#  740: 'HAND_FANS',
#  741: 'HAND_FILES',
#  742: 'HAND_POLISHERS',
#  743: 'HAND_SAWS',
#  744: 'HAND_TRUCKS',
#  745: 'HARD_DRIVES_AND_SSDS',
#  746: 'HARD_DRIVE_AND_SSD_ADAPTER_CABLES',
#  747: 'HARMONICAS',
#  748: 'HATS_AND_CAPS',
#  749: 'HEADBOARDS',
#  750: 'HEADLAMPS',
#  751: 'HEADPHONES',
#  752: 'HEADPIECES_TIARAS_AND_HEADBANDS',
#  753: 'HEARING_AIDS',
#  754: 'HEARING_PROTECTORS',
#  755: 'HEATER_CORES',
#  756: 'HEATING_PADS',
#  757: 'HEAT_GUNS',
#  758: 'HEDGE_TRIMMERS',
#  759: 'HEEL_CUPS',
#  760: 'HOCKEY_GLOVES',
#  761: 'HOLE_PUNCHES',
#  762: 'HOME_APPLIANCE_CONTACTORS_AND_RELAYS',
#  763: 'HOME_BOTTLE_STANDS',
#  764: 'HOME_HEATERS',
#  765: 'HOME_OFFICE_DESKS',
#  766: 'HOME_SHELVES',
#  767: 'HOME_THEATERS',
#  768: 'HONEY',
#  769: 'HONEY_EXTRACTORS',
#  770: 'HOOD_HINGES',
#  771: 'HOOKAHS',
#  772: 'HORSE_SADDLES',
#  773: 'HOSE_CLAMP_PLIERS',
#  774: 'HOSPITAL_BEDS',
#  775: 'HOT_DOG_MACHINES',
#  776: 'HOT_WATER_BOTTLES',
#  777: 'HOUSEHOLD_CLEANING_WAXES',
#  778: 'HOUSE_FENCES',
#  779: 'HOVERBOARDS',
#  780: 'HUMIDIFIERS_AND_VAPORIZERS',
#  781: 'HUMIDORS',
#  782: 'HYDRAULIC_VEHICLE_JACKS',
#  783: 'HYDROPHILIC_COTTON',
#  784: 'HYGROMETERS',
#  785: 'ICE_BUCKETS',
#  786: 'ICE_CREAM_MACHINES',
#  787: 'ICE_MAKERS',
#  788: 'IDENTIFICATION_AND_PRESENTATION_CARDS',
#  789: 'IDLER_ARMS',
#  790: 'IGNITION_CONTROL_MODULES',
#  791: 'IGNITION_SWITCH_ACTUATORS',
#  792: 'IMPACT_WRENCHES',
#  793: 'INDOOR_CURTAINS_AND_BLINDS',
#  794: 'INDUSTRIAL_AND_COMMERCIAL_BAG_SEALERS',
#  795: 'INDUSTRIAL_AND_COMMERCIAL_SCALES',
#  796: 'INDUSTRIAL_BLENDERS',
#  797: 'INDUSTRIAL_COOKING_OVENS',
#  798: 'INDUSTRIAL_DOUGH_KNEADERS',
#  799: 'INDUSTRIAL_ICE_CREAM_MACHINES',
#  800: 'INDUSTRIAL_PULLEYS',
#  801: 'INDUSTRIAL_SAWS',
#  802: 'INFLATABLE_BALL_PITS',
#  803: 'INFLATABLE_BOUNCE_HOUSES',
#  804: 'INFLATABLE_POOLS',
#  805: 'INFLATABLE_SLIDES',
#  806: 'INFLATABLE_SOFAS',
#  807: 'INJECTION_PUMPS',
#  808: 'INK_CARTRIDGES',
#  809: 'INSECTICIDES',
#  810: 'INSTANT_COFFEE',
#  811: 'INSTRUMENT_AMPLIFIERS',
#  812: 'INSTRUMENT_CABLES',
#  813: 'INTEGRATED_CIRCUITS',
#  814: 'INTERACTIVE_GAMING_FIGURES',
#  815: 'INTERCOOLER_HOSES',
#  816: 'INTERDENTAL_BRUSHES',
#  817: 'IP_TELEPHONES',
#  818: 'IRONS',
#  819: 'IRRIGATION_SPRINKLERS',
#  820: 'IRRIGATION_VALVES',
#  821: 'ISOPROPYL_ALCOHOLS',
#  822: 'JACKETS_AND_COATS',
#  823: 'JAMS',
#  824: 'JEWELRY_BOXES',
#  825: 'JEWELRY_DISPLAYS',
#  826: 'JUICERS',
#  827: 'JUICES',
#  828: 'JUMPSUITS_AND_OVERALLS',
#  829: 'JUMP_ROPES',
#  830: 'KATANA_SWORDS',
#  831: 'KEYBOARD_AND_DIGITAL_PIANO_STANDS',
#  832: 'KEYBOARD_AND_MOUSE_KITS',
#  833: 'KEYBOARD_AND_PIANO_PEDALS',
#  834: 'KEYBOARD_CONTROLLERS',
#  835: 'KEYCHAINS',
#  836: 'KEY_RACKS',
#  837: 'KIDS_PLAYHOUSES',
#  838: 'KIDS_TABLES_AND_CHAIRS_SETS',
#  839: 'KIDS_TENTS',
#  840: 'KIDS_TRICYCLES',
#  841: 'KIDS_WALKIE_TALKIES',
#  842: 'KID_SKATEBOARDS',
#  843: 'KINESIOLOGY_TAPES',
#  844: 'KITCHEN_APRONS',
#  845: 'KITCHEN_BOWLS',
#  846: 'KITCHEN_CABINETS',
#  847: 'KITCHEN_CABINET_ORGANIZERS',
#  848: 'KITCHEN_FAUCETS',
#  849: 'KITCHEN_FURNITURE',
#  850: 'KITCHEN_GRATERS',
#  851: 'KITCHEN_KNIVES',
#  852: 'KITCHEN_MOLDS',
#  853: 'KITCHEN_MORTARS',
#  854: 'KITCHEN_PLAYSETS',
#  855: 'KITCHEN_POTS',
#  856: 'KITCHEN_RANGE_HOODS',
#  857: 'KITCHEN_SHOVELS_AND_SPATULAS',
#  858: 'KITCHEN_SINKS',
#  859: 'KITCHEN_SINK_CADDY_ORGANIZERS',
#  860: 'KITCHEN_THERMOMETERS',
#  861: 'KITCHEN_TONGS',
#  862: 'KITCHEN_TOWELS',
#  863: 'KITES',
#  864: 'KITESURF_BOARDS',
#  865: 'KNEE_BRACES_SUPPORTS',
#  866: 'KNITTING_NEEDLES',
#  867: 'LABEL_MAKERS',
#  868: 'LADDERS',
#  869: 'LAMINATORS',
#  870: 'LAMP_HOLDERS',
#  871: 'LAPTOP_BATTERIES',
#  872: 'LAPTOP_BRIEFCASES',
#  873: 'LAPTOP_CHARGERS',
#  874: 'LAPTOP_HOUSINGS',
#  875: 'LAPTOP_KEYBOARDS',
#  876: 'LAPTOP_LCD_SCREENS',
#  877: 'LAPTOP_LOCKS',
#  878: 'LAPTOP_SKINS',
#  879: 'LAPTOP_STANDS',
#  880: 'LASER_LEVELS',
#  881: 'LASER_MEASURES',
#  882: 'LASER_POINTERS',
#  883: 'LASER_PRINTER_DRUMS',
#  884: 'LATEX_ENAMEL_AND_ACRYLIC_PAINTS',
#  885: 'LATHES',
#  886: 'LAUNDRY_BASKETS',
#  887: 'LAUNDRY_ROOM_CABINETS',
#  888: 'LAWN_MOWER_BLADES',
#  889: 'LCD_DISPLAYS',
#  890: 'LEARNING_TOY_LAPTOPS',
#  891: 'LED_STAGE_LIGHTS',
#  892: 'LED_STRIPS',
#  893: 'LEGGINGS',
#  894: 'LENS_FILTERS',
#  895: 'LENS_HOODS',
#  896: 'LENTILS',
#  897: 'LIFE_JACKETS',
#  898: 'LIGHTERS',
#  899: 'LIGHT_BULBS',
#  900: 'LIGHT_STANDS',
#  901: 'LINEMAN_PLIERS',
#  902: 'LINGERIE_SETS',
#  903: 'LIPSTICKS',
#  904: 'LIP_BALMS',
#  905: 'LIP_GLOSSES',
#  906: 'LIQUID_HAND_AND_BODY_SOAPS',
#  907: 'LIQUORS',
#  908: 'LIVING_ROOM_SETS',
#  909: 'LOAFERS_AND_OXFORDS',
#  910: 'LONGBOARDS',
#  911: 'LUGGAGE_ORGANIZERS',
#  912: 'LUGGAGE_TAGS',
#  913: 'LUMBAR_AND_ABDOMINAL_BRACES',
#  914: 'LUNCHBOXES',
#  915: 'MAF_SENSORS',
#  916: 'MAGAZINES',
#  917: 'MAGNETIC_COMPASSES',
#  918: 'MAGNETIC_WELDING_HOLDERS',
#  919: 'MAGNIFYING_GLASSES',
#  920: 'MAKEUP_BRUSHES',
#  921: 'MAKEUP_ILLUMINATORS',
#  922: 'MAKEUP_REMOVERS',
#  923: 'MAKEUP_SPONGES',
#  924: 'MAKEUP_TRAIN_CASES',
#  925: 'MAKEUP_VANITIES',
#  926: 'MALE_MASTURBATORS',
#  927: 'MALE_UNDERWEAR',
#  928: 'MANGA',
#  929: 'MANICURE_AND_PEDICURE_DRILLS',
#  930: 'MANNEQUINS',
#  931: 'MANUAL_GRAIN_MILLS',
#  932: 'MANUAL_HAMMERS',
#  933: 'MANUAL_HOISTS',
#  934: 'MANUAL_SCREWDRIVERS',
#  935: 'MANUAL_TROLLEYS',
#  936: 'MAP_SENSORS',
#  937: 'MARKERS_AND_HIGHLIGHTERS',
#  938: 'MARKING_AND_WARNING_TAPES',
#  939: 'MARTIAL_ARTS_AND_BOXING_GLOVES',
#  940: 'MARTIAL_ARTS_BELTS',
#  941: 'MARTIAL_ARTS_CHEST_GUARDS',
#  942: 'MARTIAL_ARTS_FOOT_GUARDS',
#  943: 'MASCARAS',
#  944: 'MASSAGE_SOFAS',
#  945: 'MATE_GOURDS',
#  946: 'MATE_SETS',
#  947: 'MATTRESSES',
#  948: 'MDF_BOARDS',
#  949: 'MEAT_GRINDERS',
#  950: 'MEAT_HOOKS',
#  951: 'MEDICAL_WALKERS',
#  952: 'MEDICINE_BALLS',
#  953: 'MEGAPHONES',
#  954: 'MEMORY_CARDS',
#  955: 'MEMORY_CARD_READERS',
#  956: 'MENSTRUAL_CUPS',
#  957: 'MEN_SWIMWEAR',
#  958: 'MERCHANDISER_REFRIGERATORS',
#  959: 'METAL_DETECTORS',
#  960: 'METAL_NAILS',
#  961: 'METAL_WIRES',
#  962: 'MICROCONTROLLERS',
#  963: 'MICRODERMABRASION_MACHINES',
#  964: 'MICROMETERS',
#  965: 'MICROPHONES',
#  966: 'MICROPHONE_STANDS',
#  967: 'MICROSCOPES',
#  968: 'MICROWAVES',
#  969: 'MICROWAVE_KEYPADS',
#  970: 'MICRO_ROTARY_TOOLS',
#  971: 'MILK',
#  972: 'MILK_EXTRACTORS',
#  973: 'MINI_COMPONENT_SYSTEMS',
#  974: 'MINI_PCS',
#  975: 'MIRRORS',
#  976: 'MIRROR_BALLS',
#  977: 'MIXERS',
#  978: 'MOBILE_DEVICE_CHARGERS',
#  979: 'MODELISM_SERVO_MOTORS',
#  980: 'MODEMS',
#  981: 'MONEY_BOXES',
#  982: 'MONOCULARS',
#  983: 'MOTORCYCLE_AND_ALL_TERRAIN_VEHICLE_LOADING_RAMPS',
#  984: 'MOTORCYCLE_BATTERIES',
#  985: 'MOTORCYCLE_CARBURETORS',
#  986: 'MOTORCYCLE_CASES',
#  987: 'MOTORCYCLE_CDI_MODULES',
#  988: 'MOTORCYCLE_CHEST_PROTECTORS',
#  989: 'MOTORCYCLE_CLUTCH_COVERS',
#  990: 'MOTORCYCLE_CRASH_BARS',
#  991: 'MOTORCYCLE_DISTRIBUTION_CHAINS',
#  992: 'MOTORCYCLE_EXHAUSTS',
#  993: 'MOTORCYCLE_FAIRINGS',
#  994: 'MOTORCYCLE_FENDERS',
#  995: 'MOTORCYCLE_GASOLINE_TANKS',
#  996: 'MOTORCYCLE_GEARBOXES',
#  997: 'MOTORCYCLE_GLOVES',
#  998: 'MOTORCYCLE_GRAB_BARS',
#  999: 'MOTORCYCLE_HANDLEBARS',
#  ...}

# %%
data.head()
# Out:
#                                                       title  label_quality  \
# 473424    Kit 04 Jogo De Lençol De Berço Em Malha 3 Pcs ...              0
# 7519083   Bomba Submersa 450 W Agua Suja Turva Limpa Bsv...              1
# 19488607                           Nadador Tiburon Ys1378-5              1
# 16895633                  Máscara Angry Birds 6un Imbatível              0
# 10369454  Aparador Fruteira Madeira De Demolição 1 Gavet...              0
#
#           language  category  priorities
# 473424           1       114        6245
# 7519083          1      1360           4
# 19488607         0      1155          54
# 16895633         1      1102         486
# 10369454         1      1288        1075

# %% [markdown]
# <hr>

# %%
sp = int(len(data) * 0.8) # Split Point

# %%
full = pd.concat([data[['title']], test[['title']]])

# %%
X_full = full.title

# %%
X_full.str.split().str.len().max()
# Out:
# 29

# %%
n_most_common_words = 133 # 128985 -> more than once
# 60k went to 842
max_len = 60
tokenizer = Tokenizer(num_words=n_most_common_words, char_level=True,
                      filters=None,
                      lower=True,
                      oov_token='¬')

# %%
# %%time

tokenizer.fit_on_texts(X_full)
sequences = tokenizer.texts_to_sequences(X_full)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

X_go = pad_sequences(sequences, maxlen=max_len)
# Out:
# Found 135 unique tokens.
# CPU times: user 31.1 s, sys: 422 ms, total: 31.5 s
# Wall time: 31.3 s

# %%
n_toks = len(tokenizer.word_counts) + 1
n_toks
# Out:
# 136

# %%
sp2 = len(data)
X_train, y_train = X_go[:sp], data.category.values[:sp]
X_test, y_test = X_go[sp:sp2], data.category.values[sp:sp2]
X_train.shape, X_test.shape
# Out:
# ((1100658, 60), (275165, 60))

# %%
class_weights = (1 / pd.Series(y_train).value_counts()).to_dict()

# %%
sample_weight = np.vectorize(class_weights.get)(y_train)

# %%
n_classes = len(np.unique((data.category.values)))

# %%
emb_dim = 256
seq_units = 128
drop = .1

model = Sequential()
model.add(Embedding(n_toks, emb_dim, input_length=X_train.shape[1]))
model.add(SpatialDropout1D(drop)) # maybe should remove because of rare words...
model.add(Bidirectional(GRU(seq_units, return_sequences=True, dropout=0.1,recurrent_dropout=0.1)))
model.add(GlobalMaxPool1D())
# model.add(Dense(n_classes, activation="relu"))
# model.add(Dropout(0.1))
# model.add(LSTM(seq_units, dropout=drop, recurrent_dropout=drop))
# model.add(LSTM(seq_units, dropout=drop, recurrent_dropout=drop))
# model.add(Dense(seq_units, activation='relu'))
model.add(Dense(n_classes, activation='softmax'))
model.compile(optimizer=RMSprop(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])
print(model.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0929 20:17:10.302148 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0929 20:17:10.311200 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0929 20:17:10.312438 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0929 20:17:10.322748 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0929 20:17:10.326821 140186173687552 deprecation.py:506] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0929 20:17:10.658133 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0929 20:17:10.660920 140186173687552 deprecation_wrapper.py:119] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3622: The name tf.log is deprecated. Please use tf.math.log instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 60, 256)           34816
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 60, 256)           0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 60, 256)           295680
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1588)              408116
# =================================================================
# Total params: 738,612
# Trainable params: 738,612
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
rel = data.label_quality.values[sp:sp2]

# %%
# %%time

epochs = 400
batch_size = 1024
history = model.fit(X_train[:n], y_train[:n], epochs=epochs, batch_size=batch_size,
#                     validation_data = val,
                    validation_split=0.2,
                    sample_weight = sample_weight[:n],
                    callbacks=[EarlyStopping(monitor='val_loss',patience=1, min_delta=1e-8)],
                   )
# Out:
# W0929 20:17:28.199965 140186173687552 deprecation.py:323] From /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 880526 samples, validate on 220132 samples
# Epoch 1/400
# 880526/880526 [==============================] - 94s 106us/step - loss: 0.0089 - sparse_categorical_accuracy: 0.1144 - val_loss: 0.0066 - val_sparse_categorical_accuracy: 0.3206
# Epoch 2/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0055 - sparse_categorical_accuracy: 0.4194 - val_loss: 0.0047 - val_sparse_categorical_accuracy: 0.4928
# Epoch 3/400
# 880526/880526 [==============================] - 93s 106us/step - loss: 0.0042 - sparse_categorical_accuracy: 0.5404 - val_loss: 0.0039 - val_sparse_categorical_accuracy: 0.5770
# Epoch 4/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0036 - sparse_categorical_accuracy: 0.6005 - val_loss: 0.0034 - val_sparse_categorical_accuracy: 0.6191
# Epoch 5/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0032 - sparse_categorical_accuracy: 0.6362 - val_loss: 0.0031 - val_sparse_categorical_accuracy: 0.6444
# Epoch 6/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0030 - sparse_categorical_accuracy: 0.6599 - val_loss: 0.0029 - val_sparse_categorical_accuracy: 0.6643
# Epoch 7/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0028 - sparse_categorical_accuracy: 0.6766 - val_loss: 0.0028 - val_sparse_categorical_accuracy: 0.6760
# Epoch 8/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0027 - sparse_categorical_accuracy: 0.6886 - val_loss: 0.0027 - val_sparse_categorical_accuracy: 0.6850
# Epoch 9/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0026 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 0.6924
# Epoch 10/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0025 - sparse_categorical_accuracy: 0.7055 - val_loss: 0.0026 - val_sparse_categorical_accuracy: 0.6986
# Epoch 11/400
# 880526/880526 [==============================] - 211s 240us/step - loss: 0.0024 - sparse_categorical_accuracy: 0.7115 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7031
# Epoch 12/400
# 880526/880526 [==============================] - 98s 111us/step - loss: 0.0024 - sparse_categorical_accuracy: 0.7169 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7066
# Epoch 13/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0023 - sparse_categorical_accuracy: 0.7211 - val_loss: 0.0025 - val_sparse_categorical_accuracy: 0.7101
# Epoch 14/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0023 - sparse_categorical_accuracy: 0.7245 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 0.7123
# Epoch 15/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0023 - sparse_categorical_accuracy: 0.7280 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 0.7165
# Epoch 16/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0022 - sparse_categorical_accuracy: 0.7309 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 0.7177
# Epoch 17/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0022 - sparse_categorical_accuracy: 0.7338 - val_loss: 0.0024 - val_sparse_categorical_accuracy: 0.7200
# Epoch 18/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0022 - sparse_categorical_accuracy: 0.7359 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7221
# Epoch 19/400
# 880526/880526 [==============================] - 125s 142us/step - loss: 0.0022 - sparse_categorical_accuracy: 0.7381 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7235
# Epoch 20/400
# 880526/880526 [==============================] - 92s 105us/step - loss: 0.0021 - sparse_categorical_accuracy: 0.7406 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7246
# Epoch 21/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0021 - sparse_categorical_accuracy: 0.7421 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7260
# Epoch 22/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0021 - sparse_categorical_accuracy: 0.7438 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7276
# Epoch 23/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0021 - sparse_categorical_accuracy: 0.7453 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7285
# Epoch 24/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0021 - sparse_categorical_accuracy: 0.7466 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7294
# Epoch 25/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7482 - val_loss: 0.0023 - val_sparse_categorical_accuracy: 0.7310
# Epoch 26/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7495 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7316
# Epoch 27/400
# 880526/880526 [==============================] - 116s 131us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7508 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7329
# Epoch 28/400
# 880526/880526 [==============================] - 93s 106us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7517 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7350
# Epoch 29/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7527 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7351
# Epoch 30/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7543 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7354
# Epoch 31/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7548 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7365
# Epoch 32/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7372
# Epoch 33/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0020 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7384
# Epoch 34/400
# 880526/880526 [==============================] - 147s 168us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7388
# Epoch 35/400
# 880526/880526 [==============================] - 92s 105us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7393
# Epoch 36/400
# 880526/880526 [==============================] - 92s 104us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7590 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7402
# Epoch 37/400
# 880526/880526 [==============================] - 152s 173us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7600 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7406
# Epoch 38/400
# 880526/880526 [==============================] - 101s 114us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7605 - val_loss: 0.0022 - val_sparse_categorical_accuracy: 0.7414
# Epoch 39/400
# 880526/880526 [==============================] - 130s 148us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7612 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7418
# Epoch 40/400
# 880526/880526 [==============================] - 131s 149us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7619 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7418
# Epoch 41/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7622 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7428
# Epoch 42/400
# 880526/880526 [==============================] - 131s 149us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7631 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7433
# Epoch 43/400
# 880526/880526 [==============================] - 132s 150us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7631 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7431
# Epoch 44/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7637 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7441
# Epoch 45/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7647 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7450
# Epoch 46/400
# 880526/880526 [==============================] - 132s 150us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7652 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7447
# Epoch 47/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0019 - sparse_categorical_accuracy: 0.7651 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7457
# Epoch 48/400
# 880526/880526 [==============================] - 134s 152us/step - loss: 0.0018 - sparse_categorical_accuracy: 0.7659 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7457
# Epoch 49/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0018 - sparse_categorical_accuracy: 0.7664 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7467
# Epoch 50/400
# 880526/880526 [==============================] - 132s 150us/step - loss: 0.0018 - sparse_categorical_accuracy: 0.7672 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7466
# Epoch 51/400
# 880526/880526 [==============================] - 133s 151us/step - loss: 0.0018 - sparse_categorical_accuracy: 0.7672 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7471
# Epoch 52/400
# 880526/880526 [==============================] - 92s 105us/step - loss: 0.0018 - sparse_categorical_accuracy: 0.7681 - val_loss: 0.0021 - val_sparse_categorical_accuracy: 0.7469
# CPU times: user 2h 27min 29s, sys: 13min 40s, total: 2h 41min 9s
# Wall time: 1h 33min 34s

# %%
# %%time

prediction_val = model.predict_classes(X_test, batch_size=1024,verbose=1)
print('Val:', bas(y_test, prediction_val))

rel = data.label_quality.values[sp:]
print('Rel:', bas(y_test[rel == 0], prediction_val[rel == 0]))
# Out:
# 275165/275165 [==============================] - 12s 42us/step
# Val: 0.746003992400835
# Rel: 0.8065548550490427
# CPU times: user 48.8 s, sys: 2.44 s, total: 51.3 s
# Wall time: 12.7 s
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show();

# %%
val_proba = model.predict_proba(X_test, batch_size=1024,verbose=1)
test_proba = model.predict_proba(X_go[sp2:], batch_size=1024,verbose=1)
# Out:
# 275165/275165 [==============================] - 10s 35us/step
# 246955/246955 [==============================] - 9s 36us/step

# %%
val_proba = pd.DataFrame(val_proba)
test_proba = pd.DataFrame(test_proba)

# %%
# %%time
val_proba.to_csv('../ensemb3/val_lstm_char_unproc.csv', index = False, header = False)
test_proba.to_csv('../ensemb3/test_lstm_char_unproc.csv', index = False, header = False)
# Out:
# CPU times: user 11min 24s, sys: 30.4 s, total: 11min 55s
# Wall time: 12min 5s
